# %% [markdown]
# ## Data analysis
# * get sence of variables and distributions
#
# https://www.kaggle.com/code/fedi1996/house-prices-data-cleaning-viz-and-modeling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_train=pd.read_csv('../data/house-prices-advanced-regression-techniques/train.csv')
data_train['train']=1

data_test=pd.read_csv('../data/house-prices-advanced-regression-techniques/test.csv')
data_test['train']=0

data_all=pd.concat([data_train,data_test])
data_all=data_all.set_index('Id')

# %%
data_all.hist(bins=50,figsize=(20,15));

# %%
data_all.select_dtypes(include=np.number).columns.tolist()
# Out:
# ['MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice',
#  'train']

# %% [markdown]
# Substantional amount of missing values in attributes
# 'Alley','FireplaceQu','PoolQC', 'Fence','MiscFeature'

# %%
data.info()

# %% [markdown]
# data['Street']

# %%
data.describe()

# %% [markdown]
# ## Data preprocessing
# dealing with missing values

# %%
import missingno as msno

msno.matrix(data_all.sort_values(by='SalePrice'))
# Out:
# <AxesSubplot:>

# %%
percent_Nan = [(c, data_all[c].isna().mean()*100) for c in data_all]
Nan_percent = pd.DataFrame(percent_Nan, columns=["column_name", "percentage"])
Nan_percent=Nan_percent.sort_values(by='percentage',ascending=False)
Nan_percent[Nan_percent['percentage']>50]
# Out:
# Empty DataFrame
# Columns: [column_name, percentage]
# Index: []

# %%
data_all=data_all.drop(['PoolQC','MiscFeature','Alley','Fence'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-700daddd3055> in <module>
# ----> 1 data_all=data_all.drop(['PoolQC','MiscFeature','Alley','Fence'],axis=1)
#
# ~/anaconda3/envs/data_analysis/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# ~/anaconda3/envs/data_analysis/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/anaconda3/envs/data_analysis/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/anaconda3/envs/data_analysis/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['PoolQC' 'MiscFeature' 'Alley' 'Fence'] not found in axis"

# %%
msno.matrix(data_all.sort_values(by='SalePrice'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-904a0a7bbc7a> in <module>
# ----> 1 msno.matrix(data_all.sort_values(by='SalePrice'))
#
# NameError: name 'msno' is not defined
