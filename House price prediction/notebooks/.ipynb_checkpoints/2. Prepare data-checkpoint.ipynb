# %% [markdown]
# # Preparing data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_train=pd.read_csv('../data/house-prices-advanced-regression-techniques/train.csv')
print('train size={}'.format(data_train.shape))

data_test=pd.read_csv('../data/house-prices-advanced-regression-techniques/test.csv')
print('train test={}'.format(data_test.shape))
# Out:
# train size=(1460, 81)
# train test=(1459, 80)

# %% [markdown]
# ## Preparing data for processing
#
# ### Cleaning
#
# * columns with > 0.90 missing values <br>['PoolQC', 'MiscFeature', 'Alley']
#
# * most of the values present (see the 75 quantile below) in these variables are 0, thus these features can be cleared during the data preprocessing step.<br>
# ['BsmtFinSF2','LowQualFinSF','BsmtHalfBath','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal']
#
# * imbalance classes big_class_ratio>=0.90<br>
# ['Street','Utilities','LandSlope','Condition2','RoofMatl','BsmtCond','Heating','CentralAir','Electrical','Functional','GarageQual','GarageCond','PavedDrive','MiscFeature']
#
# * Highly correlated features r2>0.80 <br>
#  'YearBuilt','GarageYrBlt'
#  'GarageCars','GarageArea'
#  'TotRmsAbvGrd','GrLivArea'
#  'TotalBsmtSF','1stFlrSF'
#
# ### Feature engineering
# * total house ares TotalSF=TotalBsmtSF+TotRmsAbvGrd+2ndFlrSF
# * number of bathrooms =

# %%
################################################################
## Cleaning
################################################################

empty_columns=['PoolQC','MiscFeature','Alley','Fence']
#'BsmtHalfBath'
lot_of_zeros=['BsmtFinSF2','LowQualFinSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal']
imbalance_classes=['Street','Utilities','LandSlope','Condition2','RoofMatl','BsmtCond','Heating','CentralAir','Electrical','Functional','GarageQual','GarageCond','PavedDrive','MiscFeature']
correlated_features=['GarageYrBlt','GarageArea','GrLivArea','1stFlrSF']

drop_columns=empty_columns+lot_of_zeros+imbalance_classes+correlated_features

data_train_cl=data_train.drop(drop_columns,axis=1)
print(len(drop_columns))


# NA for Basement section means no basement in the house
values = {"BsmtQual": 'NoBsmt', "BsmtCond": 'NoBsmt',"BsmtFinType1":'NoBsmt',"BsmtFinType2":'NoBsmt',"BsmtExposure":'NoBsmt'}
data_train_cl.fillna(value=values,inplace=True)

# NA in 'FireplaceQu' means no FirePlace in the house (missing ratio 0.486468)
data_train_cl.fillna(value={"FireplaceQu":"NoFirePlace"}, inplace=True)

# NA for Garage section means no Garage in the house (0.054471)
values = {"GarageType": 'NoGarage', "GarageFinish":"NoGarage","GarageQual":"NoGarage","GarageCond":"NoGarage"}
data_train_cl.fillna(value=values,inplace=True)

# replace 'LotFrontage' NA with median value (0.166495)
data_train_cl.fillna(value={'LotFrontage':np.nanmedian(data_train_cl['LotFrontage'])},inplace=True)

# left features with missing ratio (0.005)
data_train_cl.dropna(inplace=True)


#######################################################
# data_train_cl['HouseAge']=data_train_cl['YrSold']-data_train_cl['YearBuilt']
# data_train_cl['Time_From_Remodel']=data_train_cl['YrSold']-data_train_cl['YearRemodAdd']

# # strange remodeled early than built
# data_train_cl.drop(data_train_cl[data_train_cl['Time_From_Remodel']<0].index,inplace=True)

# data_train_cl['TotalSF']=data_train_cl['TotalBsmtSF']+data_train_cl['TotRmsAbvGrd']+data_train_cl['2ndFlrSF']
# data_train_cl['TotalBaths']=data_train_cl['FullBath']+data_train_cl['HalfBath']

# data_train_cl.drop(columns=['TotalBsmtSF','TotRmsAbvGrd','2ndFlrSF'],inplace=True)
# data_train_cl.drop(columns=['FullBath','HalfBath'],inplace=True)
# Out:
# 29

# %% [markdown]
# ## Feature Engineering

# %%
data_train_cl['HouseAge']=data_train_cl['YrSold']-data_train_cl['YearBuilt']
data_train_cl['Time_From_Remodel']=data_train_cl['YrSold']-data_train_cl['YearRemodAdd']
data_train_cl['TotalSF']=data_train_cl['TotalBsmtSF']+data_train_cl['TotRmsAbvGrd']+data_train_cl['2ndFlrSF']
data_train_cl['TotalBaths']=data_train_cl['FullBath']+data_train_cl['HalfBath']+data_train_cl['BsmtHalfBath']+data_train_cl['BsmtFullBath']

data_train_cl.drop(columns=['TotalBsmtSF','TotRmsAbvGrd','2ndFlrSF'],inplace=True)
data_train_cl.drop(columns=['FullBath','HalfBath'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/data_analysis/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BBathsmtFull'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-571a28fbd31a> in <module>
#       2 data_train_cl['Time_From_Remodel']=data_train_cl['YrSold']-data_train_cl['YearRemodAdd']
#       3 data_train_cl['TotalSF']=data_train_cl['TotalBsmtSF']+data_train_cl['TotRmsAbvGrd']+data_train_cl['2ndFlrSF']
# ----> 4 data_train_cl['TotalBaths']=data_train_cl['FullBath']+data_train_cl['HalfBath']+data_train_cl['BsmtHalfBath']+data_train_cl['BBathsmtFull']
#       5
#       6 data_train_cl.drop(columns=['TotalBsmtSF','TotRmsAbvGrd','2ndFlrSF'],inplace=True)
#
# ~/anaconda3/envs/data_analysis/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/anaconda3/envs/data_analysis/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'BBathsmtFull'

# %%
data_train_cl.corr()['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice            1.000000
# OverallQual          0.792084
# TotalSF              0.735868
# GarageCars           0.640228
# TotalBaths           0.569041
# YearBuilt            0.523109
# YearRemodAdd         0.507339
# MasVnrArea           0.479554
# Fireplaces           0.468968
# BsmtFinSF1           0.385961
# LotFrontage          0.333946
# WoodDeckSF           0.324710
# OpenPorchSF          0.314302
# LotArea              0.265372
# BsmtFullBath         0.225084
# BsmtUnfSF            0.215751
# BedroomAbvGr         0.171930
# MoSold               0.045116
# Id                  -0.025327
# YrSold              -0.026162
# OverallCond         -0.076282
# MSSubClass          -0.082816
# KitchenAbvGr        -0.137414
# Time_From_Remodel   -0.509143
# HouseAge            -0.523432
# Name: SalePrice, dtype: float64

# %%
# Out:
# SalePrice            1.000000
# OverallQual          0.792084
# GarageCars           0.640228
# TotalBsmtSF          0.617630
# FullBath             0.563726
# TotRmsAbvGrd         0.537623
# YearBuilt            0.523109
# YearRemodAdd         0.507339
# MasVnrArea           0.479554
# Fireplaces           0.468968
# BsmtFinSF1           0.385961
# LotFrontage          0.333946
# WoodDeckSF           0.324710
# 2ndFlrSF             0.323444
# OpenPorchSF          0.314302
# HalfBath             0.282143
# LotArea              0.265372
# BsmtFullBath         0.225084
# BsmtUnfSF            0.215751
# BedroomAbvGr         0.171930
# MoSold               0.045116
# Id                  -0.025327
# YrSold              -0.026162
# OverallCond         -0.076282
# MSSubClass          -0.082816
# KitchenAbvGr        -0.137414
# Time_From_Remodel   -0.509143
# HouseAge            -0.523432
# Name: SalePrice, dtype: float64

# %%
data_train_cl.drop(data_train_cl[data_train_cl['Time_From_Remodel']<0].index,inplace=True)

# %%
data_train_cl['HouseAge'].min()
# Out:
# 0

# %%
plt.figure(figsize=(14,12))
correlation = data_train_cl.corr()
sns.heatmap(correlation, mask = correlation <0.7, linewidth=0.5)
# Out:
# <AxesSubplot:>
